# %% [markdown]
# Plato's Pizza Project

# %%
import numpy as np
import pandas as pd

file_path='../data/01_raw/Data Model - Pizza Sales.xlsx'
df = pd.read_excel(file_path, parse_dates=[['order_date', 'order_time']]).rename(columns={'order_date_order_time': 'order_datetime'})
# Out:
# /tmp/ipykernel_65577/3218319156.py:5: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df = pd.read_excel(file_path, parse_dates=[['order_date', 'order_time']]).rename(columns={'order_date_order_time': 'order_datetime'})

# %%
df.head()
# Out:
#        order_datetime  order_details_id  order_id       pizza_id  quantity  \
# 0 2015-01-01 11:38:36                 1         1     hawaiian_m         1
# 1 2015-01-01 11:57:40                 2         2  classic_dlx_m         1
# 2 2015-01-01 11:57:40                 3         2  five_cheese_l         1
# 3 2015-01-01 11:57:40                 4         2    ital_supr_l         1
# 4 2015-01-01 11:57:40                 5         2     mexicana_m         1
#
#    unit_price  total_price pizza_size pizza_category  \
# 0       13.25        13.25          M        Classic
# 1       16.00        16.00          M        Classic
# 2       18.50        18.50          L         Veggie
# 3       20.75        20.75          L        Supreme
# 4       16.00        16.00          M         Veggie
#
#                                    pizza_ingredients  \
# 0           Sliced Ham, Pineapple, Mozzarella Cheese
# 1  Pepperoni, Mushrooms, Red Onions, Red Peppers,...
# ...

# %%
# Check for missing data in each column
missing_columns = df.columns[df.isnull().any()].tolist()
print("Columns with missing data:", missing_columns)
# Out:
# Columns with missing data: []

# %%
df.columns
# Out:
# Index(['order_details_id', 'order_id', 'pizza_id', 'quantity', 'order_date',
#        'order_time', 'unit_price', 'total_price', 'pizza_size',
#        'pizza_category', 'pizza_ingredients', 'pizza_name'],
#       dtype='object')

# %%
# Identify columns with corrupted data
corrupted_columns = []
numeric_columns = df.select_dtypes(include=['float', 'int']).columns.tolist()

for column in numeric_columns:
    try:
        df[column].astype(float)
    except ValueError:
        corrupted_columns.append(column)
print("Columns with potentially corrupted data:", corrupted_columns)
# Out:
# Columns with potentially corrupted data: []

# %%
#check for corrupted data in columns with string data type
corrupted_string_columns = []
for column in df.select_dtypes(include='object').columns:
    try:
        df[column].astype(str)
    except UnicodeDecodeError:
        corrupted_string_columns.append(column)
print("Columns with potentially corrupted string data:", corrupted_string_columns)
# Out:
# Columns with potentially corrupted string data: []

# %%
df['quantity'].fillna(df['quantity'].mean(), inplace=True)
#to replace any NaN values with mean of column- although there dont seem to be any

# %%
df
# Out:
#        order_details_id  order_id       pizza_id  quantity order_date  \
# 0                     1         1     hawaiian_m         1 2015-01-01
# 1                     2         2  classic_dlx_m         1 2015-01-01
# 2                     3         2  five_cheese_l         1 2015-01-01
# 3                     4         2    ital_supr_l         1 2015-01-01
# 4                     5         2     mexicana_m         1 2015-01-01
# ...                 ...       ...            ...       ...        ...
# 48615             48616     21348  ckn_alfredo_m         1 2015-12-31
# 48616             48617     21348  four_cheese_l         1 2015-12-31
# 48617             48618     21348   napolitana_s         1 2015-12-31
# 48618             48619     21349     mexicana_l         1 2015-12-31
# 48619             48620     21350      bbq_ckn_s         1 2015-12-31
#
#       order_time  unit_price  total_price pizza_size pizza_category  \
# ...

# %%
# Out:
#    order_details_id  order_id       pizza_id  quantity order_date order_time  \
# 0                 1         1     hawaiian_m         1 2015-01-01   11:38:36
# 1                 2         2  classic_dlx_m         1 2015-01-01   11:57:40
# 2                 3         2  five_cheese_l         1 2015-01-01   11:57:40
# 3                 4         2    ital_supr_l         1 2015-01-01   11:57:40
# 4                 5         2     mexicana_m         1 2015-01-01   11:57:40
#
#    unit_price  total_price pizza_size pizza_category  \
# 0       13.25        13.25          M        Classic
# 1       16.00        16.00          M        Classic
# 2       18.50        18.50          L         Veggie
# 3       20.75        20.75          L        Supreme
# 4       16.00        16.00          M         Veggie
#
#                                    pizza_ingredients  \
# 0           Sliced Ham, Pineapple, Mozzarella Cheese
# 1  Pepperoni, Mushrooms, Red Onions, Red Peppers,...
# ...

# %%
#export the data in a format ready for Tableau
df.to_csv('cleaned_data.csv', index=False)

# %%
#join date and time columns and cast it as a data type
